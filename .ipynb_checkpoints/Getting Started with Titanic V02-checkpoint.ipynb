# %% [markdown]
# # Titanic - Machine Learning from Disaster
# ![Titanic Image](https://miro.medium.com/max/1400/1*TD1TlRu96o_gDrM-NiBwpQ.jpeg)
# ## Kaggle competition - Luciano Guerra
# [Kaggle](https://www.kaggle.com/c/titanic/data)
#
# ### Overview
#
# The data has been split into two groups:
#
# - training set (train.csv)
# - test set (test.csv)
#
# The training set should be used to build your machine learning models. For the training set, we provide the outcome (also known as the “ground truth”) for each passenger. Your model will be based on “features” like passengers’ gender and class. You can also use feature engineering to create new features.
#
# The test set should be used to see how well your model performs on unseen data. For the test set, we do not provide the ground truth for each passenger. It is your job to predict these outcomes. For each passenger in the test set, use the model you trained to predict whether or not they survived the sinking of the Titanic.
#
# We also include gender_submission.csv, a set of predictions that assume all and only female passengers survive, as an example of what a submission file should look like.
#
# ### Data Dictionary
#
# Variable | Definition | Key
# - | - | -
# survival | Survival | 0 = No, 1 = Yes
# pclass |Ticket class | 1 = 1st, 2 = 2nd, 3 = 3rd
# sex	| Sex	| |
# Age	|Age in years | |
# sibsp	| # of siblings / spouses aboard the Titanic ||
# parch | # of parents / children aboard the Titanic	||
# ticket | Ticket number	||
# fare | Passenger fare	||
# cabin | Cabin number	||
# embarked | Port of Embarkation	| C = Cherbourg, Q = Queenstown, S = Southampton
#
# ### Variable Notes
#
# __pclass__: A proxy for socio-economic status (SES)
# 1st = Upper
# 2nd = Middle
# 3rd = Lower
#
# __age__: Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# __sibsp__: The dataset defines family relations in this way...
# Sibling = brother, sister, stepbrother, stepsister
# Spouse = husband, wife (mistresses and fiancés were ignored)
#
# __parch__: The dataset defines family relations in this way...
# Parent = mother, father
# Child = daughter, son, stepdaughter, stepson
# Some children travelled only with a nanny, therefore parch=0 for them.

# %% [markdown]
# ## Start ML project
# ### Predefined Steps as Hands On Machine Learning _(Auréline Géron)_
# 1. Frame the Problem and Look at the Big Picture
# 2. Get the data
# 3. Explore the data insights
# 4. Prepare the data
# 5. Explore many different models
# 6. Fine-Tune your model and combine them into a great solution
# 7. Present your solution
# 8. Launch, monitor and maintain your system

# %% [markdown]
# ## 1. Frame the Problem
# This project takes part in a series of projects to improve my ML skills. This is the first project made and it should be based in a popular Kaggle competition. The target should be to obtain a good result in the Kaggle competition.
#
# This good result should be if the accuracy in the test data is higher than 0.98.
#
# The solution of this project should be a .csv file with the correct structure to be submited in the Kaggle form.

# %% [markdown]
# ## 2. Get the Data
#
# Data is provided by Kaggle to perform the competition

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
for dirname, _, filenames in os.walk('./data'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ./data/titanic.zip
# ./data/train.csv
# ./data/test.csv
# ./data/gender_submission.csv

# %% [markdown]
# ## 3. Explore the data

# %%
train = pd.read_csv('./data/train.csv')
test = pd.read_csv('./data/test.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# Train data include labels, so we have to divide between features and labels

# %%
train_feat = train.drop(['Survived'], axis=1)
train_lab = pd.concat([train.PassengerId, train.Survived], 
                      axis=1,
                      keys=[train.PassengerId.name, train.Survived.name])
train_feat.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
train_lab.head()
# Out:
#    PassengerId  Survived
# 0            1         0
# 1            2         1
# 2            3         1
# 3            4         1
# 4            5         0

# %%
if train_feat.PassengerId.is_unique:
    train_feat.set_index('PassengerId', inplace=True)
    train_lab.set_index('PassengerId', inplace=True)
    print("Index updated")
# Out:
# Index updated

# %%
train_feat.head()
# Out:
#              Pclass                                               Name  \
# PassengerId
# 1                 3                            Braund, Mr. Owen Harris
# 2                 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                 3                             Heikkinen, Miss. Laina
# 4                 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                 3                           Allen, Mr. William Henry
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# 1              male  22.0      1      0         A/5 21171   7.2500   NaN
# 2            female  38.0      1      0          PC 17599  71.2833   C85
# 3            female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 4            female  35.0      1      0            113803  53.1000  C123
# 5              male  35.0      0      0            373450   8.0500   NaN
#
#             Embarked
# PassengerId
# 1                  S
# 2                  C
# 3                  S
# 4                  S
# 5                  S

# %%
train_lab.head()
# Out:
#              Survived
# PassengerId
# 1                   0
# 2                   1
# 3                   1
# 4                   1
# 5                   0

# %%
train_feat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    891 non-null    int64
#  1   Name      891 non-null    object
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Ticket    891 non-null    object
#  7   Fare      891 non-null    float64
#  8   Cabin     204 non-null    object
#  9   Embarked  889 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 76.6+ KB

# %% [markdown]
# In a first view we can see there are 891 records. But not all features are completed.
# - Age: we lost multiple records of Age. Too much information to loose. So we must decide which strategy could be the best to solve this problem. Options:
#     - Deleting Rows with missing values.
#     - Impute missing values for continous variable.
#     - Other imputation methods.
#     - Using Algorithms that support missing values.
#     - Prediction of missing values.
#     - Imputation using Deep Learning Library - Datawig
# - Cabin: We just have 204 records. Not enough to consider the info in this feature good for training. So we delete this feature.The rows which are having one or more columns values as null can also be dropped.
# - Embarked: We just lost 2 records. So we can asume to lost this information, deleting this two records.

# %% [markdown]
# >We shall use "Explore the data" to modify the data and fullfill lost records and delete not useful information. Otherwise, we shall call "Prepare the data", to modify the data to adapt to train the model.

# %% [markdown]
# Check the 'Embarked' records lost

# %%
train_feat[train_feat.Embarked.isna()]
# Out:
#              Pclass                                       Name     Sex   Age  \
# PassengerId
# 62                1                        Icard, Miss. Amelie  female  38.0
# 830               1  Stone, Mrs. George Nelson (Martha Evelyn)  female  62.0
#
#              SibSp  Parch  Ticket  Fare Cabin Embarked
# PassengerId
# 62               0      0  113572  80.0   B28      NaN
# 830              0      0  113572  80.0   B28      NaN

# %% [markdown]
# We can see both were in the same cabin. We can see, as well, the Ticket is the same number and the Fare is identical.
# I shall try to understand if we can see any relation with similar records.

# %%
train_feat.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
train_feat[55:70]
# Out:
#              Pclass                                Name     Sex   Age  SibSp  \
# PassengerId
# 56                1                   Woolner, Mr. Hugh    male   NaN      0
# 57                2                   Rugg, Miss. Emily  female  21.0      0
# 58                3                 Novel, Mr. Mansouer    male  28.5      0
# 59                2        West, Miss. Constance Mirium  female   5.0      1
# 60                3  Goodwin, Master. William Frederick    male  11.0      5
# 61                3               Sirayanian, Mr. Orsen    male  22.0      0
# 62                1                 Icard, Miss. Amelie  female  38.0      0
# 63                1         Harris, Mr. Henry Birkhardt    male  45.0      1
# 64                3               Skoog, Master. Harald    male   4.0      3
# 65                1               Stewart, Mr. Albert A    male   NaN      0
# 66                3            Moubarek, Master. Gerios    male   NaN      1
# 67                2        Nye, Mrs. (Elizabeth Ramell)  female  29.0      0
# 68                3            Crease, Mr. Ernest James    male  19.0      0
# 69                3     Andersson, Miss. Erna Alexandra  female  17.0      4
# 70                3                   Kink, Mr. Vincenz    male  26.0      2
#
#              Parch      Ticket     Fare Cabin Embarked
# PassengerId
# 56               0       19947  35.5000   C52        S
# 57               0  C.A. 31026  10.5000   NaN        S
# 58               0        2697   7.2292   NaN        C
# 59               2  C.A. 34651  27.7500   NaN        S
# 60               2     CA 2144  46.9000   NaN        S
# 61               0        2669   7.2292   NaN        C
# 62               0      113572  80.0000   B28      NaN
# 63               0       36973  83.4750   C83        S
# 64               2      347088  27.9000   NaN        S
# 65               0    PC 17605  27.7208   NaN        C
# 66               1        2661  15.2458   NaN        C
# 67               0  C.A. 29395  10.5000   F33        S
# 68               0   S.P. 3464   8.1583   NaN        S
# 69               2     3101281   7.9250   NaN        S
# 70               0      315151   8.6625   NaN        S

# %%
train_feat[825:835]
# Out:
#              Pclass                                       Name     Sex    Age  \
# PassengerId
# 826               3                            Flynn, Mr. John    male    NaN
# 827               3                               Lam, Mr. Len    male    NaN
# 828               2                      Mallet, Master. Andre    male   1.00
# 829               3               McCormack, Mr. Thomas Joseph    male    NaN
# 830               1  Stone, Mrs. George Nelson (Martha Evelyn)  female  62.00
# 831               3    Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.00
# 832               2            Richards, Master. George Sibley    male   0.83
# 833               3                             Saad, Mr. Amin    male    NaN
# 834               3                     Augustsson, Mr. Albert    male  23.00
# 835               3                     Allum, Mr. Owen George    male  18.00
#
#              SibSp  Parch           Ticket     Fare Cabin Embarked
# PassengerId
# 826              0      0           368323   6.9500   NaN        Q
# 827              0      0             1601  56.4958   NaN        S
# 828              0      2  S.C./PARIS 2079  37.0042   NaN        C
# 829              0      0           367228   7.7500   NaN        Q
# 830              0      0           113572  80.0000   B28      NaN
# 831              1      0             2659  14.4542   NaN        C
# 832              1      1            29106  18.7500   NaN        S
# 833              0      0             2671   7.2292   NaN        C
# 834              0      0           347468   7.8542   NaN        S
# 835              0      0             2223   8.3000   NaN        S

# %% [markdown]
# According with this info we shall try to check the average for the Fare at each different Embarked group.

# %%
train_feat.groupby(by=train_feat.Embarked.name).Fare.describe()
# Out:
#           count       mean        std     min       25%    50%        75%  \
# Embarked
# C         168.0  59.954144  83.912994  4.0125  13.69795  29.70  78.500025
# Q          77.0  13.276030  14.188047  6.7500   7.75000   7.75  15.500000
# S         644.0  27.079812  35.887993  0.0000   8.05000  13.00  27.900000
#
#                max
# Embarked
# C         512.3292
# Q          90.0000
# S         263.0000

# %% [markdown]
# According with this table, the C class have an average closer to the Fare value of our records of study.

# %% [markdown]
# Checking it visually

# %%
train_feat.boxplot(column='Fare', by='Embarked', figsize=(4,4))
# Out:
# <AxesSubplot:title={'center':'Fare'}, xlabel='Embarked'>

# %% [markdown]
# This appears that the only option not to be an outlier should be to belong to the C class.

# %%
train_feat.groupby(by=train_feat.Embarked.name).median()
# Out:
#           Pclass   Age  SibSp  Parch   Fare
# Embarked
# C            1.0  29.0    0.0    0.0  29.70
# Q            3.0  27.0    0.0    0.0   7.75
# S            3.0  28.0    0.0    0.0  13.00

# %% [markdown]
# So we assume C as the lost class

# %%
train_feat['Embarked'].replace({np.nan : 'C'}, inplace=True)

# %%
train_feat.Embarked.unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %% [markdown]
# #### Secondly we remove the 'Cabin' column

# %%
train_feat.drop(labels='Cabin',axis=1, inplace=True)

# %%
train_feat.head()
# Out:
#              Pclass                                               Name  \
# PassengerId
# 1                 3                            Braund, Mr. Owen Harris
# 2                 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                 3                             Heikkinen, Miss. Laina
# 4                 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                 3                           Allen, Mr. William Henry
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Embarked
# PassengerId
# 1              male  22.0      1      0         A/5 21171   7.2500        S
# 2            female  38.0      1      0          PC 17599  71.2833        C
# 3            female  26.0      0      0  STON/O2. 3101282   7.9250        S
# 4            female  35.0      1      0            113803  53.1000        S
# 5              male  35.0      0      0            373450   8.0500        S

# %% [markdown]
# ### At this point we have to decide what to do with lost data in Age

# %% [markdown]
# Impute missing values with Mean/Median:

# %%
train_feat.Age.mean(), train_feat.Age.median()
# Out:
# (29.69911764705882, 28.0)

# %%
train_feat.groupby(by=train_feat.Parch.name).Age.median()
# Out:
# Parch
# 0    30.0
# 1    23.0
# 2    16.5
# 3    24.0
# 4    42.5
# 5    39.0
# 6    43.0
# Name: Age, dtype: float64

# %%
train_feat.groupby(by=train_feat.SibSp.name).Age.median()
# Out:
# SibSp
# 0    29.0
# 1    30.0
# 2    23.0
# 3     9.5
# 4     6.5
# 5    11.0
# 8     NaN
# Name: Age, dtype: float64

# %%
Pclass_age = train_feat.groupby(by=train_feat.Pclass.name).Age.median().to_dict()
Pclass_age
# Out:
# {1: 37.0, 2: 29.0, 3: 24.0}

# %% [markdown]
# We can see a slightly difference with the age related to the Pclass in the boat. So we are going to change the NaN with the median (more robust than mean for outliers) of each Pclass.

# %%
train_temp1 = train_feat.loc[(train_feat.Pclass == 1) & (train_feat.Age.isna())].fillna(Pclass_age[1])
train_temp2 = train_feat.loc[(train_feat.Pclass == 2) & (train_feat.Age.isna())].fillna(Pclass_age[2])
train_temp3 = train_feat.loc[(train_feat.Pclass == 3) & (train_feat.Age.isna())].fillna(Pclass_age[3])

# %%
train_feat.loc[train_temp1.index, :] = train_temp1[:]
train_feat.loc[train_temp2.index, :] = train_temp2[:]
train_feat.loc[train_temp3.index, :] = train_temp3[:]

# %%
train_feat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    891 non-null    int64
#  1   Name      891 non-null    object
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Ticket    891 non-null    object
#  7   Fare      891 non-null    float64
#  8   Embarked  891 non-null    object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 101.9+ KB

# %%
del train_temp1, train_temp2, train_temp3

# %% [markdown]
# ## 4. Prepare the data

# %% [markdown]
# We shall make a firt overview of the actual data

# %%
train_feat.head()
# Out:
#              Pclass                                               Name  \
# PassengerId
# 1                 3                            Braund, Mr. Owen Harris
# 2                 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                 3                             Heikkinen, Miss. Laina
# 4                 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                 3                           Allen, Mr. William Henry
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Embarked
# PassengerId
# 1              male  22.0      1      0         A/5 21171   7.2500        S
# 2            female  38.0      1      0          PC 17599  71.2833        C
# 3            female  26.0      0      0  STON/O2. 3101282   7.9250        S
# 4            female  35.0      1      0            113803  53.1000        S
# 5              male  35.0      0      0            373450   8.0500        S

# %% [markdown]
# We have 3 categorical features: Pclass, Sex and Embarked. Name and Ticket seem to have no relevant information. So:
# - We can remove Name and Ticket.
# - We can transform Pclass, Sex and Embarked in different columns for each category.

# %%
train_feat.drop(['Name', 'Ticket'], axis=1, inplace=True)

# %%
train_feat
# Out:
#              Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# PassengerId
# 1                 3    male  22.0      1      0   7.2500        S
# 2                 1  female  38.0      1      0  71.2833        C
# 3                 3  female  26.0      0      0   7.9250        S
# 4                 1  female  35.0      1      0  53.1000        S
# 5                 3    male  35.0      0      0   8.0500        S
# ...             ...     ...   ...    ...    ...      ...      ...
# 887               2    male  27.0      0      0  13.0000        S
# 888               1  female  19.0      0      0  30.0000        S
# 889               3  female  24.0      1      2  23.4500        S
# 890               1    male  26.0      0      0  30.0000        C
# 891               3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 7 columns]

# %%
train_feat = pd.get_dummies(train_feat, columns=['Pclass', 'Sex', 'Embarked'])

# %%
train_feat
# Out:
#               Age  SibSp  Parch     Fare  Pclass_1  Pclass_2  Pclass_3  \
# PassengerId
# 1            22.0      1      0   7.2500         0         0         1
# 2            38.0      1      0  71.2833         1         0         0
# 3            26.0      0      0   7.9250         0         0         1
# 4            35.0      1      0  53.1000         1         0         0
# 5            35.0      0      0   8.0500         0         0         1
# ...           ...    ...    ...      ...       ...       ...       ...
# 887          27.0      0      0  13.0000         0         1         0
# 888          19.0      0      0  30.0000         1         0         0
# 889          24.0      1      2  23.4500         0         0         1
# 890          26.0      0      0  30.0000         1         0         0
# 891          32.0      0      0   7.7500         0         0         1
#
#              Sex_female  Sex_male  Embarked_C  Embarked_Q  Embarked_S
# PassengerId
# 1                     0         1           0           0           1
# 2                     1         0           1           0           0
# 3                     1         0           0           0           1
# 4                     1         0           0           0           1
# 5                     0         1           0           0           1
# ...                 ...       ...         ...         ...         ...
# 887                   0         1           0           0           1
# 888                   1         0           0           0           1
# 889                   1         0           0           0           1
# 890                   0         1           1           0           0
# 891                   0         1           0           1           0
#
# [891 rows x 12 columns]

# %%
train_feat.rename(columns={'Pclass_1' : 'C1', 'Pclass_2' : 'C2', 'Pclass_3' : 'C3',
                          'Sex_female': 'female', 'Sex_male' : 'male',
                          'Embarked_C': 'E_C', 'Embarked_Q' : 'E_Q', 'Embarked_S' : 'E_S'}, 
                 inplace=True)

# %%
train_feat
# Out:
#               Age  SibSp  Parch     Fare  C1  C2  C3  female  male  E_C  E_Q  \
# PassengerId
# 1            22.0      1      0   7.2500   0   0   1       0     1    0    0
# 2            38.0      1      0  71.2833   1   0   0       1     0    1    0
# 3            26.0      0      0   7.9250   0   0   1       1     0    0    0
# 4            35.0      1      0  53.1000   1   0   0       1     0    0    0
# 5            35.0      0      0   8.0500   0   0   1       0     1    0    0
# ...           ...    ...    ...      ...  ..  ..  ..     ...   ...  ...  ...
# 887          27.0      0      0  13.0000   0   1   0       0     1    0    0
# 888          19.0      0      0  30.0000   1   0   0       1     0    0    0
# 889          24.0      1      2  23.4500   0   0   1       1     0    0    0
# 890          26.0      0      0  30.0000   1   0   0       0     1    1    0
# 891          32.0      0      0   7.7500   0   0   1       0     1    0    1
#
#              E_S
# PassengerId
# 1              1
# 2              0
# 3              1
# 4              1
# 5              1
# ...          ...
# 887            1
# 888            1
# 889            1
# 890            0
# 891            0
#
# [891 rows x 12 columns]

# %% [markdown]
# Now we are ready to visualze some data to see if any behaviour is detected.

# %%
train_lab
# Out:
#              Survived
# PassengerId
# 1                   0
# 2                   1
# 3                   1
# 4                   1
# 5                   0
# ...               ...
# 887                 0
# 888                 1
# 889                 0
# 890                 1
# 891                 0
#
# [891 rows x 1 columns]

# %% [markdown]
# ### Let's calculate some data and visualize to take conclusions
# #### According with gender

# %%
wo_surv = train_lab[train_feat.female == 1]['Survived'].sum() / train_feat.female.sum()
ma_surv = train_lab[train_feat.female == 0]['Survived'].sum() / (train_feat.female.count() - train_feat.female.sum())
wo_surv, ma_surv
# Out:
# (0.7420382165605095, 0.18890814558058924)

# %% [markdown]
# We can see clearly women survived much more than men

# %% [markdown]
# #### According with class

# %%
C1_surv = train_lab[train_feat.C1 == 1]['Survived'].sum() / train_feat.C1.sum()
C2_surv = train_lab[train_feat.C2 == 1]['Survived'].sum() / train_feat.C2.sum()
C3_surv = train_lab[train_feat.C3 == 1]['Survived'].sum() / train_feat.C3.sum()
C1_surv, C2_surv, C3_surv
# Out:
# (0.6296296296296297, 0.47282608695652173, 0.24236252545824846)

# %% [markdown]
# In a first revision, we can see a clear behaviour. First class survive much more than third class. So this variables are relevant for the model.

# %% [markdown]
# #### According with embark

# %%
EC_surv = train_lab[train_feat.E_C == 1]['Survived'].sum() / train_feat.E_C.sum()
EQ_surv = train_lab[train_feat.E_Q == 1]['Survived'].sum() / train_feat.E_Q.sum()
ES_surv = train_lab[train_feat.E_S == 1]['Survived'].sum() / train_feat.E_S.sum()
EC_surv, EQ_surv, ES_surv
# Out:
# (0.5588235294117647, 0.38961038961038963, 0.33695652173913043)

# %% [markdown]
# It seems that embarking on different cities takes into account in the survivor rate.

# %%
train_feat.corr()
# Out:
#              Age     SibSp     Parch      Fare        C1        C2        C3  \
# Age     1.000000 -0.243526 -0.171095  0.123784  0.384431  0.029242 -0.355026
# SibSp  -0.243526  1.000000  0.414838  0.159651 -0.054582 -0.055932  0.092548
# Parch  -0.171095  0.414838  1.000000  0.216225 -0.017633 -0.000734  0.015790
# Fare    0.123784  0.159651  0.216225  1.000000  0.591711 -0.118557 -0.413333
# C1      0.384431 -0.054582 -0.017633  0.591711  1.000000 -0.288585 -0.626738
# C2      0.029242 -0.055932 -0.000734 -0.118557 -0.288585  1.000000 -0.565210
# C3     -0.355026  0.092548  0.015790 -0.413333 -0.626738 -0.565210  1.000000
# female -0.078421  0.114631  0.245489  0.182333  0.098013  0.064746 -0.137143
# male    0.078421 -0.114631 -0.245489 -0.182333 -0.098013 -0.064746  0.137143
# E_C     0.049550 -0.061970 -0.013725  0.273614  0.305181 -0.127763 -0.158965
# E_Q    -0.081658 -0.026354 -0.081228 -0.117216 -0.155342 -0.127301  0.237449
# E_S     0.007763  0.070941  0.063036 -0.166603 -0.170379  0.192061 -0.009511
#
#           female      male       E_C       E_Q       E_S
# Age    -0.078421  0.078421  0.049550 -0.081658  0.007763
# SibSp   0.114631 -0.114631 -0.061970 -0.026354  0.070941
# Parch   0.245489 -0.245489 -0.013725 -0.081228  0.063036
# Fare    0.182333 -0.182333  0.273614 -0.117216 -0.166603
# C1      0.098013 -0.098013  0.305181 -0.155342 -0.170379
# C2      0.064746 -0.064746 -0.127763 -0.127301  0.192061
# C3     -0.137143  0.137143 -0.158965  0.237449 -0.009511
# female  1.000000 -1.000000  0.090223  0.074115 -0.125722
# male   -1.000000  1.000000 -0.090223 -0.074115  0.125722
# E_C     0.090223 -0.090223  1.000000 -0.149345 -0.784064
# E_Q     0.074115 -0.074115 -0.149345  1.000000 -0.496624
# E_S    -0.125722  0.125722 -0.784064 -0.496624  1.000000

# %%
train_feat.corr().style.background_gradient(cmap='viridis').set_properties(**{'font-size' : '12px'})
# Out:
# <style type="text/css">
# #T_44ebb_row0_col0, #T_44ebb_row1_col1, #T_44ebb_row2_col2, #T_44ebb_row3_col3, #T_44ebb_row4_col4, #T_44ebb_row5_col5, #T_44ebb_row6_col6, #T_44ebb_row7_col7, #T_44ebb_row8_col8, #T_44ebb_row9_col9, #T_44ebb_row10_col10, #T_44ebb_row11_col11 {
#   background-color: #fde725;
#   color: #000000;
#   font-size: 12px;
# }
# #T_44ebb_row0_col1, #T_44ebb_row4_col6, #T_44ebb_row6_col0, #T_44ebb_row6_col3, #T_44ebb_row6_col4, #T_44ebb_row6_col5, #T_44ebb_row7_col8, #T_44ebb_row8_col2, #T_44ebb_row8_col7, #T_44ebb_row9_col11, #T_44ebb_row11_col9, #T_44ebb_row11_col10 {
#   background-color: #440154;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row0_col2 {
#   background-color: #481769;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row0_col3, #T_44ebb_row0_col5, #T_44ebb_row7_col10, #T_44ebb_row11_col6 {
#   background-color: #2c738e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row0_col4, #T_44ebb_row2_col7 {
#   background-color: #27ad81;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row0_col6 {
#   background-color: #443983;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row0_col7 {
#   background-color: #24868e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row0_col8 {
#   background-color: #1f9a8a;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row0_col9, #T_44ebb_row5_col8 {
#   background-color: #23888e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row0_col10 {
#   background-color: #38598c;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row0_col11, #T_44ebb_row1_col6, #T_44ebb_row1_col8 {
#   background-color: #26828e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row1_col0 {
#   background-color: #481f70;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row1_col2, #T_44ebb_row2_col1, #T_44ebb_row10_col6 {
#   background-color: #1f978b;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row1_col3, #T_44ebb_row1_col9, #T_44ebb_row7_col5 {
#   background-color: #29798e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row1_col4, #T_44ebb_row3_col0 {
#   background-color: #2e6d8e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row1_col5, #T_44ebb_row3_col1, #T_44ebb_row8_col4 {
#   background-color: #31668e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row1_col7 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row1_col10 {
#   background-color: #33638d;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row1_col11 {
#   background-color: #228b8d;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row2_col0 {
#   background-color: #472f7d;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row2_col3, #T_44ebb_row7_col4 {
#   background-color: #25838e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row2_col4 {
#   background-color: #2c718e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row2_col5 {
#   background-color: #2e6f8e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row2_col6 {
#   background-color: #2a778e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row2_col8 {
#   background-color: #2c728e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row2_col9, #T_44ebb_row6_col7 {
#   background-color: #27808e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row2_col10, #T_44ebb_row9_col5, #T_44ebb_row10_col5, #T_44ebb_row11_col4 {
#   background-color: #375a8c;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row2_col11 {
#   background-color: #238a8d;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row3_col2, #T_44ebb_row5_col9, #T_44ebb_row7_col11 {
#   background-color: #2d718e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row3_col4 {
#   background-color: #5cc863;
#   color: #000000;
#   font-size: 12px;
# }
# #T_44ebb_row3_col5, #T_44ebb_row7_col1, #T_44ebb_row9_col6 {
#   background-color: #365c8d;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row3_col6, #T_44ebb_row10_col2 {
#   background-color: #472e7c;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row3_col7, #T_44ebb_row3_col9 {
#   background-color: #21a685;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row3_col8 {
#   background-color: #297a8e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row3_col10, #T_44ebb_row11_col1 {
#   background-color: #3b528b;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row3_col11, #T_44ebb_row4_col11 {
#   background-color: #2f6b8e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row4_col0, #T_44ebb_row9_col7 {
#   background-color: #1e9b8a;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row4_col1, #T_44ebb_row5_col1 {
#   background-color: #463480;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row4_col2 {
#   background-color: #433e85;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row4_col3 {
#   background-color: #4ac16d;
#   color: #000000;
#   font-size: 12px;
# }
# #T_44ebb_row4_col5 {
#   background-color: #433d84;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row4_col7, #T_44ebb_row5_col11 {
#   background-color: #1e9c89;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row4_col8 {
#   background-color: #25848e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row4_col9 {
#   background-color: #25ab82;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row4_col10 {
#   background-color: #3e4c8a;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row5_col0, #T_44ebb_row8_col10 {
#   background-color: #375b8d;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row5_col2 {
#   background-color: #414287;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row5_col3, #T_44ebb_row5_col4, #T_44ebb_row6_col2, #T_44ebb_row10_col3 {
#   background-color: #404688;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row5_col6 {
#   background-color: #470e61;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row5_col7 {
#   background-color: #1f988b;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row5_col10, #T_44ebb_row11_col2 {
#   background-color: #3b518b;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row6_col1 {
#   background-color: #38588c;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row6_col8 {
#   background-color: #1fa188;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row6_col9 {
#   background-color: #2f6c8e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row6_col10, #T_44ebb_row7_col9 {
#   background-color: #218e8d;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row6_col11, #T_44ebb_row11_col7 {
#   background-color: #26818e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row7_col0 {
#   background-color: #404588;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row7_col2 {
#   background-color: #2a768e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row7_col3 {
#   background-color: #287d8e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row7_col6 {
#   background-color: #34608d;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row8_col0, #T_44ebb_row8_col5 {
#   background-color: #32648e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row8_col1 {
#   background-color: #482576;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row8_col3, #T_44ebb_row10_col11 {
#   background-color: #453882;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row8_col6 {
#   background-color: #23898e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row8_col9 {
#   background-color: #2b758e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row8_col11 {
#   background-color: #20928c;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row9_col0 {
#   background-color: #355f8d;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row9_col1 {
#   background-color: #46337f;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row9_col2 {
#   background-color: #423f85;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row9_col3 {
#   background-color: #228d8d;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row9_col4 {
#   background-color: #1fa187;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row9_col8 {
#   background-color: #25858e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row9_col10 {
#   background-color: #3d4d8a;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row10_col0 {
#   background-color: #414487;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row10_col1, #T_44ebb_row11_col3 {
#   background-color: #443b84;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_44ebb_row10_col4

# %% [markdown]
# We can see a clear relationship between male and female (-1). This is an obvious relationship and we can remove one column. Same idea could be used with Class and Embarked.
# So we can remove one column of each and check it again.

# %%
train_feat.drop(train_feat.male.name, axis=1, inplace=True, errors='ignore')
train_feat.drop(train_feat.C3.name, axis=1, inplace=True, errors='ignore')
train_feat.drop(train_feat.E_S.name, axis=1, inplace=True, errors='ignore')

# %%
train_feat.corr()
# Out:
#              Age     SibSp     Parch      Fare        C1        C2    female  \
# Age     1.000000 -0.243526 -0.171095  0.123784  0.384431  0.029242 -0.078421
# SibSp  -0.243526  1.000000  0.414838  0.159651 -0.054582 -0.055932  0.114631
# Parch  -0.171095  0.414838  1.000000  0.216225 -0.017633 -0.000734  0.245489
# Fare    0.123784  0.159651  0.216225  1.000000  0.591711 -0.118557  0.182333
# C1      0.384431 -0.054582 -0.017633  0.591711  1.000000 -0.288585  0.098013
# C2      0.029242 -0.055932 -0.000734 -0.118557 -0.288585  1.000000  0.064746
# female -0.078421  0.114631  0.245489  0.182333  0.098013  0.064746  1.000000
# E_C     0.049550 -0.061970 -0.013725  0.273614  0.305181 -0.127763  0.090223
# E_Q    -0.081658 -0.026354 -0.081228 -0.117216 -0.155342 -0.127301  0.074115
#
#              E_C       E_Q
# Age     0.049550 -0.081658
# SibSp  -0.061970 -0.026354
# Parch  -0.013725 -0.081228
# Fare    0.273614 -0.117216
# C1      0.305181 -0.155342
# C2     -0.127763 -0.127301
# female  0.090223  0.074115
# E_C     1.000000 -0.149345
# E_Q    -0.149345  1.000000

# %%
train_feat.corr().style.background_gradient(cmap='viridis').set_properties(**{'font-size' : '12px'})
# Out:
# <style type="text/css">
# #T_1e6ea_row0_col0, #T_1e6ea_row1_col1, #T_1e6ea_row2_col2, #T_1e6ea_row3_col3, #T_1e6ea_row4_col4, #T_1e6ea_row5_col5, #T_1e6ea_row6_col6, #T_1e6ea_row7_col7, #T_1e6ea_row8_col8 {
#   background-color: #fde725;
#   color: #000000;
#   font-size: 12px;
# }
# #T_1e6ea_row0_col1, #T_1e6ea_row0_col2, #T_1e6ea_row0_col6, #T_1e6ea_row1_col0, #T_1e6ea_row4_col5, #T_1e6ea_row4_col8, #T_1e6ea_row5_col3, #T_1e6ea_row5_col4, #T_1e6ea_row8_col3, #T_1e6ea_row8_col7 {
#   background-color: #440154;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row0_col3 {
#   background-color: #3f4889;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row0_col4 {
#   background-color: #1f958b;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row0_col5, #T_1e6ea_row1_col3 {
#   background-color: #3b518b;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row0_col7, #T_1e6ea_row8_col1 {
#   background-color: #443b84;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row0_col8, #T_1e6ea_row2_col8 {
#   background-color: #48186a;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row1_col2 {
#   background-color: #21918c;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row1_col4, #T_1e6ea_row1_col5 {
#   background-color: #433e85;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row1_col6 {
#   background-color: #433d84;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row1_col7, #T_1e6ea_row8_col2 {
#   background-color: #481c6e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row1_col8 {
#   background-color: #482878;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row2_col0 {
#   background-color: #481668;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row2_col1 {
#   background-color: #1f978b;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row2_col3, #T_1e6ea_row2_col6, #T_1e6ea_row6_col4 {
#   background-color: #355f8d;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row2_col4, #T_1e6ea_row6_col7 {
#   background-color: #404688;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row2_col5 {
#   background-color: #3e4a89;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row2_col7 {
#   background-color: #472a7a;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row3_col0 {
#   background-color: #355e8d;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row3_col1 {
#   background-color: #31668e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row3_col2 {
#   background-color: #31678e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row3_col4 {
#   background-color: #3bbb75;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row3_col5, #T_1e6ea_row4_col2, #T_1e6ea_row5_col6, #T_1e6ea_row6_col0, #T_1e6ea_row8_col0 {
#   background-color: #472e7c;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row3_col6 {
#   background-color: #3c4f8a;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row3_col7 {
#   background-color: #2d718e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row3_col8 {
#   background-color: #470d60;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row4_col0 {
#   background-color: #20928c;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row4_col1, #T_1e6ea_row5_col1 {
#   background-color: #463480;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row4_col3 {
#   background-color: #2ab07f;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row4_col6 {
#   background-color: #453882;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row4_col7 {
#   background-color: #2a778e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row5_col0 {
#   background-color: #3e4989;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row5_col2, #T_1e6ea_row7_col1 {
#   background-color: #46337f;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row5_col7 {
#   background-color: #46075a;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row5_col8 {
#   background-color: #460a5d;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row6_col1 {
#   background-color: #365c8d;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row6_col2 {
#   background-color: #2e6e8e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row6_col3 {
#   background-color: #39568c;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row6_col5 {
#   background-color: #38598c;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row6_col8 {
#   background-color: #414287;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row7_col0 {
#   background-color: #3d4e8a;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row7_col2 {
#   background-color: #472f7d;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row7_col3 {
#   background-color: #2f6c8e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row7_col4 {
#   background-color: #24868e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row7_col5 {
#   background-color: #472c7a;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row7_col6 {
#   background-color: #453781;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row7_col8 {
#   background-color: #440256;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row8_col4 {
#   background-color: #482576;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row8_col5 {
#   background-color: #472d7b;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# #T_1e6ea_row8_col6 {
#   background-color: #46327e;
#   color: #f1f1f1;
#   font-size: 12px;
# }
# </style>
# <table id="T_1e6ea_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Age</th>
#       <th class="col_heading level0 col1" >SibSp</th>
#       <th class="col_heading level0 col2" >Parch</th>
#       <th class="col_heading level0 col3" >Fare</th>
#       <th class="col_heading level0 col4" >C1</th>
#       <th class="col_heading level0 col5" >C2</th>
#       <th class="col_heading level0 col6" >female</th>
#       <th class="col_heading level0 col7" >E_C</th>
#       <th class="col_heading level0 col8" >E_Q</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e6ea_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_1e6ea_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_1e6ea_row0_col1" class="data row0 col1" >-0.243526</td>
#       <td id="T_1e6ea_row0_col2" class="data row0 col2" >-0.171095</td>
#       <td id="T_1e6ea_row0_col3" class="data row0 col3" >0.123784</td>
#       <td id="T_1e6ea_row0_col4" class="data row0 col4" >0.384431</td>
#       <td id="T_1e6ea_row0_col5" class="data row0 col5" >0.029242</td>
#       <td id="T_1e6ea_row0_col6" class="data row0 col6" >-0.078421</td>
#       <td id="T_1e6ea_row0_col7" class="data row0 col7" >0.049550</td>
#       <td id="T_1e6ea_row0_col8" class="data row0 col8" >-0.081658</td>
#     </tr>
#     <tr>
#       <th id="T_1e6ea_level0_row1" class="row_heading level0 row1" >SibSp</th>
#       <td id="T_1e6ea_row1_col0" class="data row1 col0" >-0.243526</td>
#       <td id="T_1e6ea_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_1e6ea_row1_col2" class="data row1 col2" >0.414838</td>
#       <td id="T_1e6ea_row1_col3" class="data row1 col3" >0.159651</td>
#       <td id="T_1e6ea_row1_col4" class="data row1 col4" >-0.054582</td>
#       <td id="T_1e6ea_row1_col5" class="data row1 col5" >-0.055932</td>
#       <td id="T_1e6ea_row1_col6" class="data row1 col6" >0.114631</td>
#       <td id="T_1e6ea_row1_col7" class="data row1 col7" >-0.061970</td>
#       <td id="T_1e6ea_row1_col8" class="data row1 col8" >-0.026354</td>
#     </tr>
#     <tr>
#       <th id="T_1e6ea_level0_row2" class="row_heading level0 row2" >Parch</th>
#       <td id="T_1e6ea_row2_col0" class="data row2 col0" >-0.171095</td>
#       <td id="T_1e6ea_row2_col1" class="data row2 col1" >0.414838</td>
#       <td id="T_1e6ea_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_1e6ea_row2_col3" class="data row2 col3" >0.216225</td>
#       <td id="T_1e6ea_row2_col4" class="data row2 col4" >-0.017633</td>
#       <td id="T_1e6ea_row2_col5" class="data row2 col5" >-0.000734</td>
#       <td id="T_1e6ea_row2_col6" class="data row2 col6" >0.245489</td>
#       <td id="T_1e6ea_row2_col7" class="data row2 col7" >-0.013725</td>
#       <td id="T_1e6ea_row2_col8" class="data row2 col8" >-0.081228</td>
#     </tr>
#     <tr>
#       <th id="T_1e6ea_level0_row3" class="row_heading level0 row3" >Fare</t

# %% [markdown]
# We can see we have still correlated features. So we could reduce the dimmension of the model without loosing any information. Best option is to apply PCA (Principal Component Analysis).
#
# But befor to apply PCA we need to normalize the data to get the best result.

# %%
train_feat.head()
# Out:
#               Age  SibSp  Parch     Fare  C1  C2  female  E_C  E_Q
# PassengerId
# 1            22.0      1      0   7.2500   0   0       0    0    0
# 2            38.0      1      0  71.2833   1   0       1    1    0
# 3            26.0      0      0   7.9250   0   0       1    0    0
# 4            35.0      1      0  53.1000   1   0       1    0    0
# 5            35.0      0      0   8.0500   0   0       0    0    0

# %% [markdown]
# But before normalize we have to take into account we have to do same procedures in test info. So we have to chek maximum values in both. Describe could help us to understand.

# %%
train_feat.describe()
# Out:
#               Age       SibSp       Parch        Fare          C1          C2  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean    29.066409    0.523008    0.381594   32.204208    0.242424    0.206510
# std     13.244532    1.102743    0.806057   49.693429    0.428790    0.405028
# min      0.420000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     22.000000    0.000000    0.000000    7.910400    0.000000    0.000000
# 50%     26.000000    0.000000    0.000000   14.454200    0.000000    0.000000
# 75%     37.000000    1.000000    0.000000   31.000000    0.000000    0.000000
# max     80.000000    8.000000    6.000000  512.329200    1.000000    1.000000
#
#            female         E_C         E_Q
# count  891.000000  891.000000  891.000000
# mean     0.352413    0.190797    0.086420
# std      0.477990    0.393150    0.281141
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000
# 75%      1.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000

# %%
test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %% [markdown]
# We can see Age and Fare are with their maximum range in train data. So the scaler cand be trained in this data.

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
train_feat[['Age', 'Fare']] = scaler.fit_transform(train_feat[['Age', 'Fare']])
train_feat.head()
# Out:
#                   Age  SibSp  Parch      Fare  C1  C2  female  E_C  E_Q
# PassengerId
# 1            0.271174      1      0  0.014151   0   0       0    0    0
# 2            0.472229      1      0  0.139136   1   0       1    1    0
# 3            0.321438      0      0  0.015469   0   0       1    0    0
# 4            0.434531      1      0  0.103644   1   0       1    0    0
# 5            0.434531      0      0  0.015713   0   0       0    0    0

# %%
train_feat.corr()
# Out:
#              Age     SibSp     Parch      Fare        C1        C2    female  \
# Age     1.000000 -0.243526 -0.171095  0.123784  0.384431  0.029242 -0.078421
# SibSp  -0.243526  1.000000  0.414838  0.159651 -0.054582 -0.055932  0.114631
# Parch  -0.171095  0.414838  1.000000  0.216225 -0.017633 -0.000734  0.245489
# Fare    0.123784  0.159651  0.216225  1.000000  0.591711 -0.118557  0.182333
# C1      0.384431 -0.054582 -0.017633  0.591711  1.000000 -0.288585  0.098013
# C2      0.029242 -0.055932 -0.000734 -0.118557 -0.288585  1.000000  0.064746
# female -0.078421  0.114631  0.245489  0.182333  0.098013  0.064746  1.000000
# E_C     0.049550 -0.061970 -0.013725  0.273614  0.305181 -0.127763  0.090223
# E_Q    -0.081658 -0.026354 -0.081228 -0.117216 -0.155342 -0.127301  0.074115
#
#              E_C       E_Q
# Age     0.049550 -0.081658
# SibSp  -0.061970 -0.026354
# Parch  -0.013725 -0.081228
# Fare    0.273614 -0.117216
# C1      0.305181 -0.155342
# C2     -0.127763 -0.127301
# female  0.090223  0.074115
# E_C     1.000000 -0.149345
# E_Q    -0.149345  1.000000

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=0.95) # 0.95 means variance between 95-99%
pca.fit(train_feat)
train_red = pca.transform(train_feat)
train_red
# Out:
# array([[ 0.24223537, -0.64509179, -0.22374592,  0.25641203, -0.15339434,
#          0.06620217],
#        [ 0.27733271, -0.33611967,  1.26031936, -0.45676272,  0.27920026,
#          0.13968515],
#        [-0.56965894,  0.02500885,  0.02276868, -0.5993356 , -0.41992389,
#          0.08855619],
#        ...,
#        [ 1.21113976,  1.3018564 , -0.12654777, -0.19760541, -0.36703747,
#          0.08391649],
#        [-0.68963366, -0.11108302,  0.91382249,  0.45576683,  0.45042235,
#          0.16120217],
#        [-0.66328289, -0.22639989, -0.31613042,  0.21066951, -0.57035532,
#          0.19932175]])

# %% [markdown]
# Now we are ready to use the data in our models.

# %% [markdown]
# ## 5. Explore many different models

# %% [markdown]
# The most popular classification algorithms are:
# - Logistic Regression
# - Naive Bayes
# - K-Nearest Neighbors
# - Decision Tree (DT)
# - Random Forest Classifier (RFC)
# - Support Vector Machines (SVM)
# - Stochastic Gradient Descent (SGD)
# - Linear Discriminant Analysis (LDA)
# - Quadratic Discriminant Analysis (QDA)
# - Gradient Boosting Classifier (GBC)
# - Ada Boost Classifier (ABC)
#
# We prepare a routine to check the best performance of all of them.

# %%
# import models we want to use
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, log_loss
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis

import matplotlib.pyplot as plt
import seaborn as sns

# %%
rf_clf = RandomForestClassifier()
ab_clf = AdaBoostClassifier()
gb_clf = GradientBoostingClassifier()
lr_clf = LogisticRegression()
sgd_clf = SGDClassifier()
svm_clf = SVC()
sgd_clf = SGDClassifier()
dt_clf = DecisionTreeClassifier()
kn_clf = KNeighborsClassifier()
gnb_clf = GaussianNB()
lda_clf = LinearDiscriminantAnalysis()
qda_clf = QuadraticDiscriminantAnalysis()

classifiers = [
    RandomForestClassifier(),
    AdaBoostClassifier(),
    GradientBoostingClassifier(),
    LogisticRegression(n_jobs=10),
    SGDClassifier(),
    SVC(),
    DecisionTreeClassifier(),
    KNeighborsClassifier(),
    GaussianNB(),
    LinearDiscriminantAnalysis(),
    QuadraticDiscriminantAnalysis()
]

log_cols = ["Classifier", "Accuracy"]
log = pd.DataFrame(columns=log_cols)

# %% [markdown]
# First of all prepare my train data to check predictions. We are working with surpervised models, so we have to use labels to verify accuracy.

# %%
X_train = pd.DataFrame(train_red)
y_train = train_lab

# %%
splits = 20
sss = StratifiedShuffleSplit(n_splits=splits, test_size=0.1, random_state=0)

X = X_train
y = y_train

acc_dict = {}

for train_index, test_index in sss.split(X,y):
    X_tr, X_ts = X.iloc[train_index], X.iloc[test_index]
    y_tr, y_ts = y.iloc[train_index], y.iloc[test_index]
    
    for clf in classifiers:
        name = clf.__class__.__name__
        clf.fit(X_tr, y_tr)
        train_predictions = clf.predict(X_ts)
        acc = accuracy_score(y_ts, train_predictions)        
        if name in acc_dict:
            acc_dict[name] += acc
        else:
            acc_dict[name] = acc
            
log.drop(log.index, axis=0)
    
for clf in acc_dict:
    acc_dict[clf] = acc_dict[clf] / splits
    log_entry = pd.DataFrame([[clf, acc_dict[clf]]], columns=log_cols)
    log = log.append(log_entry)
# Out:
# /tmp/ipykernel_2596/3555927321.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_tr, y_tr)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /tmp/ipykernel_2596/3555927321.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_tr, y_tr)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /tmp/ipykernel_2596/3555927321.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_tr, y_tr)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /tmp/ipykernel_2596/3555927321.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_tr, y_tr)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /tmp/ipykernel_2596/3555927321.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_tr, y_tr)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /tmp/ipykernel_2596/3555927321.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_tr, y_tr)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /tmp/ipykernel_2596/3555927321.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_tr, y_tr)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /tmp/ipykernel_2596/3555927321.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_tr, y_tr)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /tmp/ipykernel_2596/3555927321.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_tr, y_tr)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /tmp/ipykernel_2596/3555927321.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_tr, y_tr)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /tmp/ipykernel_2596/3555927321.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_tr, y_tr)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /tmp/ipykernel_2596/3555927321.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_tr, y_tr)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /tmp/ipykernel_2596/3555927321.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_tr, y_tr)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /tmp/ipykernel_2596/3555927321.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_tr, y_tr)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /tmp/ipykernel_2596/3555927321.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_tr, y_tr)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /tmp/ipykernel_2596/3555927321.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_tr, y_tr)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /tmp/ipykernel_2596/3555927321.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_tr, y_tr)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /tmp/ipykernel_2596/3555927321.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_tr, y_tr)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /tmp/ipykernel_2596/3555927321.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_tr, y_tr)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /tmp/ipykernel_2596/3555927321.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_tr, y_tr)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/luciano/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
plt.xlabel('Accuracy')
plt.title('Classifier Accuracy')

sns.set_color_codes("muted")
sns.barplot(x='Accuracy', y='Classifier', data=log, color='b')
# Out:
# <AxesSubplot:title={'center':'Classifier Accuracy'}, xlabel='Accuracy', ylabel='Classifier'>

# %%
log
# Out:
#                       Classifier  Accuracy
# 0         RandomForestClassifier  0.781111
# 0             AdaBoostClassifier  0.775000
# 0     GradientBoostingClassifier  0.786667
# 0             LogisticRegression  0.786111
# 0                  SGDClassifier  0.757222
# 0                            SVC  0.798333
# 0         DecisionTreeClassifier  0.762222
# 0           KNeighborsClassifier  0.770556
# 0                     GaussianNB  0.780556
# 0     LinearDiscriminantAnalysis  0.790000
# 0  QuadraticDiscriminantAnalysis  0.767222

# %% [markdown]
# So the information from this test is that SVC is the best model with an accuracy of __0.798333__

# %% [markdown]
# #### Now prepare data to submission
#
# Steps to do:
# 1. Update Index
# 2. Solve lost data
# 3. Remove Name and Ticket features
# 4. Encode categorical classes
# 5. Remove columns of C3 and EQ_S
# 6. Normalize Age and Fare
# 7. Apply PCA
# 8. Predict result and sabe submission file

# %% [markdown]
# ##### Update index

# %%
if test.PassengerId.is_unique:
    test.set_index('PassengerId', inplace=True)
    print("Index updated")
# Out:
# Index updated

# %%
test.head()
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#               Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# PassengerId
# 892          34.5      0      0   330911   7.8292   NaN        Q
# 893          47.0      1      0   363272   7.0000   NaN        S
# 894          62.0      0      0   240276   9.6875   NaN        Q
# 895          27.0      0      0   315154   8.6625   NaN        S
# 896          22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# ##### Solve lost data

# %%
test.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare
# count  418.000000  332.000000  418.000000  418.000000  417.000000
# mean     2.265550   30.272590    0.447368    0.392344   35.627188
# std      0.841838   14.181209    0.896760    0.981429   55.907576
# min      1.000000    0.170000    0.000000    0.000000    0.000000
# 25%      1.000000   21.000000    0.000000    0.000000    7.895800
# 50%      3.000000   27.000000    0.000000    0.000000   14.454200
# 75%      3.000000   39.000000    1.000000    0.000000   31.500000
# max      3.000000   76.000000    8.000000    9.000000  512.329200

# %% [markdown]
# We need to solve lost data in Age and in Fare.
#
# In Age we shall use same strategy as in training data. We shall use substitution data according with train data.

# %%
test.loc[test.Age.isna()]
# Out:
#              Pclass                                               Name  \
# PassengerId
# 902               3                                   Ilieff, Mr. Ylio
# 914               1               Flegenheim, Mrs. Alfred (Antoinette)
# 921               3                                  Samaan, Mr. Elias
# 925               3  Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"
# 928               3                                Roth, Miss. Sarah A
# ...             ...                                                ...
# 1300              3                    Riordan, Miss. Johanna Hannah""
# 1302              3                             Naughton, Miss. Hannah
# 1305              3                                 Spector, Mr. Woolf
# 1308              3                                Ware, Mr. Frederick
# 1309              3                           Peter, Master. Michael J
#
#                 Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# PassengerId
# 902            male  NaN      0      0      349220   7.8958   NaN        S
# 914          female  NaN      0      0    PC 17598  31.6833   NaN        S
# 921            male  NaN      2      0        2662  21.6792   NaN        C
# 925          female  NaN      1      2  W./C. 6607  23.4500   NaN        S
# 928          female  NaN      0      0      342712   8.0500   NaN        S
# ...             ...  ...    ...    ...         ...      ...   ...      ...
# 1300         female  NaN      0      0      334915   7.7208   NaN        Q
# 1302         female  NaN      0      0      365237   7.7500   NaN        Q
# 1305           male  NaN      0      0   A.5. 3236   8.0500   NaN        S
# 1308           male  NaN      0      0      359309   8.0500   NaN        S
# 1309           male  NaN      1      1        2668  22.3583   NaN        C
#
# [86 rows x 10 columns]

# %%
test_temp1 = test.loc[(test.Pclass == 1) & (test.Age.isna())].fillna(Pclass_age[1])
test_temp2 = test.loc[(test.Pclass == 2) & (test.Age.isna())].fillna(Pclass_age[2])
test_temp3 = test.loc[(test.Pclass == 3) & (test.Age.isna())].fillna(Pclass_age[3])

# %%
test.loc[test_temp1.index, :] = test_temp1[:]
test.loc[test_temp2.index, :] = test_temp2[:]
test.loc[test_temp3.index, :] = test_temp3[:]

# %%
test.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare
# count  418.000000  418.000000  418.000000  418.000000  417.000000
# mean     2.265550   29.321770    0.447368    0.392344   35.627188
# std      0.841838   12.904065    0.896760    0.981429   55.907576
# min      1.000000    0.170000    0.000000    0.000000    0.000000
# 25%      1.000000   23.000000    0.000000    0.000000    7.895800
# 50%      3.000000   25.000000    0.000000    0.000000   14.454200
# 75%      3.000000   36.375000    1.000000    0.000000   31.500000
# max      3.000000   76.000000    8.000000    9.000000  512.329200

# %% [markdown]
# In Fare we shall use the correlation between Fare and class.

# %%
test.loc[test.Fare.isna()]
# Out:
#              Pclass                Name   Sex   Age  SibSp  Parch Ticket  \
# PassengerId
# 1044              3  Storey, Mr. Thomas  male  60.5      0      0   3701
#
#              Fare Cabin Embarked
# PassengerId
# 1044          NaN   NaN        S

# %%
test.corr()
# Out:
#           Pclass       Age     SibSp     Parch      Fare
# Pclass  1.000000 -0.521341  0.001087  0.018721 -0.577147
# Age    -0.521341  1.000000 -0.076124 -0.052613  0.354952
# SibSp   0.001087 -0.076124  1.000000  0.306895  0.171539
# Parch   0.018721 -0.052613  0.306895  1.000000  0.230046
# Fare   -0.577147  0.354952  0.171539  0.230046  1.000000

# %% [markdown]
# We keep seen a high correlation between Fare and Pclass. So we could substitude the Fare value with the median of class 3.

# %%
med_age =test.groupby(by=test.Pclass).Fare.median()[int(test.loc[test.Fare.isna()].Pclass.values)]
ind_age = int(test.loc[test.Fare.isna()].index.values)

# %%
int(test.loc[test.Fare.isna()].index.values)
# Out:
# 1044

# %%
int(test.loc[test.Fare.isna()].Pclass.values)
# Out:
# 3

# %%
test.loc[test.Fare.isna()]
# Out:
#              Pclass                Name   Sex   Age  SibSp  Parch Ticket  \
# PassengerId
# 1044              3  Storey, Mr. Thomas  male  60.5      0      0   3701
#
#              Fare Cabin Embarked
# PassengerId
# 1044          NaN   NaN        S

# %%
train_lab[train_feat.female == 1]['Survived'].count() + train_lab[train_feat.male == 1]['Survived'].count()

# %%
test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200
